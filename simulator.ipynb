# %% [markdown]
# # PREVOĐENJE PROGRAMSKIH JEZIKA - 4. laboratorijska vježba

# %% [markdown]
# Svrha ove bilježnice je provesti vas kroz jednu od mogućnosti simulacije generiranih kodova i provjere njihove ispravnosti.

# %% [markdown]
# ## Upute za postavljanje okruženja

# %% [markdown]
# Za ispravno izvođenje ove bilježnice potrebno je pratiti sljedeće korake:
#
# 1. **Preuzimanje alata**: Preuzmite arhivu sa stranice ARM GNU Toolchain. Korisnici Windows sustava trebaju preuzeti: arm-gnu-toolchain-15.2.rel1-mingw-w64-x86_64-arm-none-eabi.zip.
#
# 2. **Konfiguracija direktorija**: Raspakirajte arhivu i mapu bin postavite izravno u direktorij u kojem se nalazi ova bilježnica.
#
# 3. **Instalacija biblioteka**: Potrebno je instalirati Python biblioteku unicorn. To možete učiniti pokretanjem ćelije koja se nalazi neposredno ispod ovih uputa.
#
# 4. **Priprema testova**: Preuzmite arhivu s testovima sa službene stranice predmeta. Sve testne mape kopirajte u direktorij tests unutar vašeg radnog direktorija.
#
# **Očekivana struktura direktorija**
#
# Prije izvršavanja bilježnice, osigurajte da vaš radni direktorij izgleda ovako:
#
# <pre>
#
# radni_direktorij/
# ├── bin/                    # Mapa s ARM alatima
# ├── GeneratorKoda           # Izvorni kod vašeg generatora
# ├── tests/                  # Mapa s testnim primjerima
# │   ├── 01_ret_broj/        # Pojedinačni testni slučaj
# │   │   ├── test.in         # Ulazni podaci
# │   │   └── test.out        # Očekivani izlaz
# │   └── ...                 # Ostali testovi
# └── simulator.ipynb         # Ova bilježnica
#
# </pre>

# %%
# %pip install unicorn
# Out:
# Requirement already satisfied: unicorn in c:\users\mance\desktop\fer\5.semestar\prevodenje-programskih-jezika\labosi_repo\ppj-labosi\.venv\lib\site-packages (2.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Simulacija

# %%
import os
import subprocess
import tempfile

import unicorn.arm_const as arm
from unicorn import Uc, UC_ARCH_ARM, UC_MODE_ARM, UC_HOOK_INTR

ARM_CODE_ADDRESS = 0x10000
ARM_CODE_SIZE = 0x4000
MEMORY_SIZE = 0x10000

arm_toolchain_path = ".\\bin"

if arm_toolchain_path not in os.environ["PATH"]:
    os.environ["PATH"] = arm_toolchain_path + os.pathsep + os.environ["PATH"]

def hook_intr(mu, intno, user_data):
    if intno == 2:
        mu.emu_stop()


def evaluate_r6(arm_code_path, expected_r6_value):
    with tempfile.TemporaryDirectory() as tmpdir:
        asm_file = os.path.join(tmpdir, "code.s")
        obj_file = os.path.join(tmpdir, "code.o")
        elf_file = os.path.join(tmpdir, "code.elf")
        bin_file = os.path.join(tmpdir, "code.bin")

        with open(arm_code_path, "r") as src, open(asm_file, "w") as dst:
            dst.write(src.read())

        try:
            subprocess.run(
                ["arm-none-eabi-as", asm_file, "-o", obj_file], capture_output=True, check=True, text=True
            )

            subprocess.run([
                "arm-none-eabi-ld",
                "-Ttext", hex(ARM_CODE_ADDRESS),
                obj_file, "-o", elf_file
            ], capture_output=True, check=True, text=True)

            subprocess.run(["arm-none-eabi-objcopy", "-O", "binary", elf_file, bin_file], capture_output=True, check=True, text=True)
        except subprocess.CalledProcessError as e:
            print("Postoji greška u generiranom kodu:")
            print(e.stderr)
            raise e

        with open(bin_file, "rb") as f:
            code = f.read()

    mu = Uc(UC_ARCH_ARM, UC_MODE_ARM)
    mu.hook_add(UC_HOOK_INTR, hook_intr)

    mu.mem_map(0x0000, 0x30000)

    mu.mem_write(ARM_CODE_ADDRESS, code)

    mu.reg_write(arm.UC_ARM_REG_SP, 0x20000)

    try:
        mu.emu_start(ARM_CODE_ADDRESS, ARM_CODE_ADDRESS + len(code))
    except Exception as e:
        pass

    r6_value = mu.reg_read(arm.UC_ARM_REG_R6)

    if r6_value & 0x80000000:
        r6_signed = r6_value - 0x100000000
    else:
        r6_signed = r6_value

    print(f"  > R6 result: {hex(r6_value)} (Signed: {r6_signed}) (Expected: {expected_r6_value})")

    return r6_signed == expected_r6_value


TESTS_FOLDER = "tests"


def run_all_tests():
    test_dirs = sorted([f for f in os.listdir(TESTS_FOLDER) if os.path.isdir(os.path.join(TESTS_FOLDER, f))])
    total = len(test_dirs)
    passed = 0
    for test_dir in test_dirs:
        test_path = os.path.join(TESTS_FOLDER, test_dir)
        print(f"Running {test_path}...")

        input_path = os.path.join(test_path, "test.in")
        output_path = os.path.join(test_path, "test.out")

        # TODO otkomentirajte subprocess koji se odnosi na jezik u kojem ste pisali Vašu laboratorijsku vježbu, ostale zakomentirajte    
        try:
            # python
            result = subprocess.run(
                f"python3 GeneratorKoda.py < {input_path}",
                shell=True, check=True, capture_output=True, text=True
            )

            # java
            # subprocess.run(f"javac GeneratorKoda.java", shell=True, check=True, capture_output=True, text=True)
            # result = subprocess.run(
            #     f"java GeneratorKoda < {input_path}",
            #     shell=True, check=True,  capture_output=True
            # )
            # C++
            # subprocess.run(f"g++ GeneratorKoda.cpp -o generator", shell=True, check=True, text=True)
            # result = subprocess.run(
            #     f"./generator < {input_path}",
            #     shell=True, check=True,  capture_output=True, text=True
            # )
        except subprocess.CalledProcessError as e:
            print("Postoji u prevođenju koda:")
            print(e.stderr)
            raise e

        with open(output_path, "r") as f:
            line = f.read().strip()
            expected_val = int(line.strip(), 10)

        if evaluate_r6("a.s", expected_val):
            print("  [PASS]")
            passed += 1
        else:
            print("  [FAIL]")

            with open(os.path.join(".", "a.s"), "r") as f1:
                with open(os.path.join(".", f"{test_dir}.s"), "w") as f2:
                    f2.write(f1.read())

    print("-" * 20)
    print(f"FINAL RESULT: {passed}/{total} tests passed.")


if __name__ == "__main__":
    run_all_tests()
# Out:
# Running tests\02_ret_broj...
#   > R6 result: 0x3 (Signed: 3) (Expected: 3)
#   [PASS]
# Running tests\e_001...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_002...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_003...
#   > R6 result: 0x2 (Signed: 2) (Expected: 2)
#   [PASS]
# Running tests\e_004...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_005...
#   > R6 result: 0xfffffffb (Signed: -5) (Expected: -5)
#   [PASS]
# Running tests\e_006...
#   > R6 result: 0x20a (Signed: 522) (Expected: 522)
#   [PASS]
# Running tests\e_007...
#   > R6 result: 0xe (Signed: 14) (Expected: 14)
#   [PASS]
# Running tests\e_008...
#   > R6 result: 0x3 (Signed: 3) (Expected: 3)
#   [PASS]
# Running tests\e_009...
#   > R6 result: 0x7 (Signed: 7) (Expected: 7)
#   [PASS]
# Running tests\e_010...
#   > R6 result: 0x5 (Signed: 5) (Expected: 5)
#   [PASS]
# Running tests\e_011...
#   > R6 result: 0xc (Signed: 12) (Expected: 12)
#   [PASS]
# Running tests\e_012...
#   > R6 result: 0xb (Signed: 11) (Expected: 11)
#   [PASS]
# Running tests\e_013...
#   > R6 result: 0xb (Signed: 11) (Expected: 11)
#   [PASS]
# Running tests\e_014...
#   > R6 result: 0x9 (Signed: 9) (Expected: 9)
#   [PASS]
# Running tests\e_015...
#   > R6 result: 0x9 (Signed: 9) (Expected: 9)
#   [PASS]
# Running tests\e_016...
#   > R6 result: 0xb (Signed: 11) (Expected: 11)
#   [PASS]
# Running tests\e_017...
#   > R6 result: 0xa (Signed: 10) (Expected: 10)
#   [PASS]
# Running tests\e_018...
#   > R6 result: 0x9 (Signed: 9) (Expected: 9)
#   [PASS]
# Running tests\e_019...
#   > R6 result: 0xa (Signed: 10) (Expected: 10)
#   [PASS]
# Running tests\e_020...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_021...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_022...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_023...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_024...
#   > R6 result: 0xffffffff (Signed: -1) (Expected: -1)
#   [PASS]
# Running tests\e_025...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_026...
#   > R6 result: 0xffffffff (Signed: -1) (Expected: -1)
#   [PASS]
# Running tests\e_027...
#   > R6 result: 0xffffffff (Signed: -1) (Expected: -1)
#   [PASS]
# Running tests\e_028...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_029...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_030...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_031...
#   > R6 result: 0xffffffff (Signed: -1) (Expected: -1)
#   [PASS]
# Running tests\e_032...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_033...
#   > R6 result: 0xfffffffe (Signed: -2) (Expected: -2)
#   [PASS]
# Running tests\e_034...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_035...
#   > R6 result: 0x25 (Signed: 37) (Expected: 37)
#   [PASS]
# Running tests\e_036...
#   > R6 result: 0x3 (Signed: 3) (Expected: 3)
#   [PASS]
# Running tests\e_037...
#   > R6 result: 0xfffffea7 (Signed: -345) (Expected: -345)
#   [PASS]
# Running tests\e_038...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_039...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_040...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_041...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_042...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_043...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_044...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_045...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_046...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_047...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_048...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_049...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_050...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_051...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_052...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_053...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_054...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_055...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_056...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_057...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_058...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_059...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_060...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_061...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_062...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_063...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_064...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_065...
#   > R6 result: 0x1d4 (Signed: 468) (Expected: 468)
#   [PASS]
# Running tests\e_066...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_067...
#   > R6 result: 0x7 (Signed: 7) (Expected: 7)
#   [PASS]
# Running tests\e_068...
#   > R6 result: 0x9 (Signed: 9) (Expected: 9)
#   [PASS]
# Running tests\e_069...
#   > R6 result: 0xffffffff (Signed: -1) (Expected: -1)
#   [PASS]
# Running tests\e_070...
#   > R6 result: 0x9 (Signed: 9) (Expected: 9)
#   [PASS]
# Running tests\e_071...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_072...
#   > R6 result: 0xffffffff (Signed: -1) (Expected: -1)
#   [PASS]
# Running tests\e_073...
#   > R6 result: 0xfffffffe (Signed: -2) (Expected: -2)
#   [PASS]
# Running tests\e_074...
#   > R6 result: 0xffffffff (Signed: -1) (Expected: -1)
#   [PASS]
# Running tests\e_075...
#   > R6 result: 0xfffffff6 (Signed: -10) (Expected: -10)
#   [PASS]
# Running tests\e_076...
#   > R6 result: 0xfffffffa (Signed: -6) (Expected: -6)
#   [PASS]
# Running tests\e_077...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_078...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_079...
#   > R6 result: 0x3 (Signed: 3) (Expected: 3)
#   [PASS]
# Running tests\e_080...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_081...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_082...
#   > R6 result: 0x3 (Signed: 3) (Expected: 3)
#   [PASS]
# Running tests\e_083...
#   > R6 result: 0x2 (Signed: 2) (Expected: 2)
#   [PASS]
# Running tests\e_084...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_085...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_086...
#   > R6 result: 0x0 (Signed: 0) (Expected: 12)
#   [FAIL]
# Running tests\e_087...
#   > R6 result: 0x0 (Signed: 0) (Expected: 12)
#   [FAIL]
# Running tests\e_088...
#   > R6 result: 0x0 (Signed: 0) (Expected: 3)
#   [FAIL]
# Running tests\e_089...
#   > R6 result: 0x0 (Signed: 0) (Expected: 12)
#   [FAIL]
# Running tests\e_090...
#   > R6 result: 0x0 (Signed: 0) (Expected: 5)
#   [FAIL]
# Running tests\e_091...
#   > R6 result: 0x0 (Signed: 0) (Expected: 1)
#   [FAIL]
# Running tests\e_092...
#   > R6 result: 0x0 (Signed: 0) (Expected: 2)
#   [FAIL]
# Running tests\e_093...
#   > R6 result: 0x0 (Signed: 0) (Expected: -100)
#   [FAIL]
# Running tests\e_094...
#   > R6 result: 0x0 (Signed: 0) (Expected: 1)
#   [FAIL]
# Running tests\e_095...
#   > R6 result: 0x0 (Signed: 0) (Expected: 2)
#   [FAIL]
# Running tests\e_096...
#   > R6 result: 0x0 (Signed: 0) (Expected: 621)
#   [FAIL]
# Running tests\e_097...
#   > R6 result: 0x0 (Signed: 0) (Expected: 47)
#   [FAIL]
# Running tests\e_098...
#   > R6 result: 0x0 (Signed: 0) (Expected: 0)
#   [PASS]
# Running tests\e_099...
#   > R6 result: 0x0 (Signed: 0) (Expected: -1056)
#   [FAIL]
# Running tests\e_100...
#   > R6 result: 0x0 (Signed: 0) (Expected: 98)
#   [FAIL]
# Running tests\e_101...
#   > R6 result: 0x1 (Signed: 1) (Expected: 1)
#   [PASS]
# Running tests\e_102...
#   > R6 result: 0x2 (Signed: 2) (Expected: 2)
#   [PASS]
# Running tests\e_103...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: -100)
#   [PASS]
# Running tests\e_104...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 1)
#   [FAIL]
# Running tests\e_105...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 2)
#   [FAIL]
# Running tests\e_106...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 621)
#   [FAIL]
# Running tests\e_107...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 47)
#   [FAIL]
# Running tests\e_108...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 0)
#   [FAIL]
# Running tests\e_109...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: -1056)
#   [FAIL]
# Running tests\e_110...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 98)
#   [FAIL]
# Running tests\e_111...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 97)
#   [FAIL]
# Running tests\e_112...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 98)
#   [FAIL]
# Running tests\e_113...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 99)
#   [FAIL]
# Running tests\e_114...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 100)
#   [FAIL]
# Running tests\e_115...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 0)
#   [FAIL]
# Running tests\e_116...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 97)
#   [FAIL]
# Running tests\e_117...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 98)
#   [FAIL]
# Running tests\e_118...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 99)
#   [FAIL]
# Running tests\e_119...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 100)
#   [FAIL]
# Running tests\e_120...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 0)
#   [FAIL]
# Running tests\e_121...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 49)
#   [FAIL]
# Running tests\e_122...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 50)
#   [FAIL]
# Running tests\e_123...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 97)
#   [FAIL]
# Running tests\e_124...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 103)
#   [FAIL]
# Running tests\e_125...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 109)
#   [FAIL]
# Running tests\e_126...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 49)
#   [FAIL]
# Running tests\e_127...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 50)
#   [FAIL]
# Running tests\e_128...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 97)
#   [FAIL]
# Running tests\e_129...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 103)
#   [FAIL]
# Running tests\e_130...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 109)
#   [FAIL]
# Running tests\e_131...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 1)
#   [FAIL]
# Running tests\e_132...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 4)
#   [FAIL]
# Running tests\e_133...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 28)
#   [FAIL]
# Running tests\e_134...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 25)
#   [FAIL]
# Running tests\e_135...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 25)
#   [FAIL]
# Running tests\e_136...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 1)
#   [FAIL]
# Running tests\e_137...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 2)
#   [FAIL]
# Running tests\e_138...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 3)
#   [FAIL]
# Running tests\e_139...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 97)
#   [FAIL]
# Running tests\e_140...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 98)
#   [FAIL]
# Running tests\e_141...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 0)
#   [FAIL]
# Running tests\e_142...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 0)
#   [FAIL]
# Running tests\e_143...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 1)
#   [FAIL]
# Running tests\e_144...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 2)
#   [FAIL]
# Running tests\e_145...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 2)
#   [FAIL]
# Running tests\e_146...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 1)
#   [FAIL]
# Running tests\e_147...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 2)
#   [FAIL]
# Running tests\e_148...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 3)
#   [FAIL]
# Running tests\e_149...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 97)
#   [FAIL]
# Running tests\e_150...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 98)
#   [FAIL]
# Running tests\e_151...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 0)
#   [FAIL]
# Running tests\e_152...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 0)
#   [FAIL]
# Running tests\e_153...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 1)
#   [FAIL]
# Running tests\e_154...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 2)
#   [FAIL]
# Running tests\e_155...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 2)
#   [FAIL]
# Running tests\e_156...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 1)
#   [FAIL]
# Running tests\e_157...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: -6)
#   [FAIL]
# Running tests\e_158...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 3)
#   [FAIL]
# Running tests\e_159...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 2)
#   [FAIL]
# Running tests\e_160...
#   > R6 result: 0xffffff9c (Signed: -100) (Expected: 0)
#   [FAIL]
# Running tests\e_161...
#   > R6 result: 0xa (Signed: 10) (Expected: 55)
#   [FAIL]
# Running tests\e_162...
#   > R6 result: 0x2 (Signed: 2) (Expected: 55)
#   [FAIL]
# Running tests\e_163...
#   > R6 result: 0x2 (Signed: 2) (Expected: 30)
#   [FAIL]
# Running tests\e_164...
#   > R6 result: 0x2 (Signed: 2) (Expected: 30)
#   [FAIL]
# Running tests\e_165...
#   > R6 result: 0x2 (Signed: 2) (Expected: 10)
#   [FAIL]
# Running tests\e_166...
#   > R6 result: 0x2 (Signed: 2) (Expected: 7)
#   [FAIL]
# Running tests\e_167...
#   > R6 result: 0x2 (Signed: 2) (Expected: 7)
#   [FAIL]
# Running tests\e_168...
#   > R6 result: 0x2 (Signed: 2) (Expected: 17)
#   [FAIL]
# Running tests\e_169...
#   > R6 result: 0x2 (Signed: 2) (Expected: 17)
#   [FAIL]
# Running tests\e_170...
#   > R6 result: 0x2 (Signed: 2) (Expected: 5)
#   [FAIL]
# Running tests\e_171...
#   > R6 result: 0x1b (Signed: 27) (Expected: 27)
#   [PASS]
# Running tests\e_172...
#   > R6 result: 0x8 (Signed: 8) (Expected: 8)
#   [PASS]
# Running tests\e_173...
#   > R6 result: 0xa (Signed: 10) (Expected: 10)
#   [PASS]
# Running tests\e_174...
#   > R6 result: 0x9 (Signed: 9) (Expected: 15)
#   [FAIL]
# Running tests\e_175...
#   > R6 result: 0x9 (Signed: 9) (Expected: 15)
#   [FAIL]
# Running tests\e_176...
#   > R6 result: 0xa (Signed: 10) (Expected: 40)
#   [FAIL]
# Running tests\e_177...
#   > R6 result: 0x9 (Signed: 9) (Expected: 45)
#   [FAIL]
# Running tests\e_178...
#   > R6 result: 0xa (Signed: 10) (Expected: 55)
#   [FAIL]
# Running tests\e_179...
#   > R6 result: 0x9 (Signed: 9) (Expected: 15)
#   [FAIL]
# Running tests\e_180...
#   > R6 result: 0x9 (Signed: 9) (Expected: 45)
#   [FAIL]
# Running tests\e_181...
#   > R6 result: 0x9 (Signed: 9) (Expected: 55)
#   [FAIL]
# Running tests\e_182...
#   > R6 result: 0xa (Signed: 10) (Expected: 90)
#   [FAIL]
# Running tests\e_183...
#   > R6 result: 0xa (Signed: 10) (Expected: 90)
#   [FAIL]
# Running tests\e_184...
#   > R6 result: 0x1 (Signed: 1) (Expected: 15)
#   [FAIL]
# Running tests\e_185...
#   > R6 result: 0x1 (Signed: 1) (Expected: 10)
#   [FAIL]
# Running tests\e_186...
#   > R6 result: 0x1 (Signed: 1) (Expected: 10)
#   [FAIL]
# Running tests\test1...
#   > R6 result: 0x47 (Signed: 71) (Expected: 71)
#   [PASS]
# --------------------
# FINAL RESULT: 94/188 tests passed.
